# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from utils import draw_strokes, draw_temporal_strokes

# %%
input_dir = "../../quickdraw"

# %%
df = pd.read_csv(
    "{}/train_simplified/owl.csv".format(input_dir),
    index_col="key_id",
    usecols=["key_id", "drawing", "word"],
    nrows=1000,
    converters={"drawing": lambda drawing: eval(drawing)})

# %%
image = draw_strokes(df.iloc[0].drawing)
plt.imshow(image)

# %%
image = draw_temporal_strokes(df.iloc[0].drawing)

fig, axs = plt.subplots(1, image.shape[0], figsize=(30, 5))
for i in range(image.shape[0]):
    axs[i].imshow(image[i])
